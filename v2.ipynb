# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# !pip install ezsheets
# !pip install schedule

import requests
from datetime import datetime
import calendar
import ezsheets
import time
import schedule

api_endpoint = 'https://openexchangerates.org/api/latest.json?app_id=042976e8e40745ef883cfc9d015e0bdb'
response = requests.get(api_endpoint)


def isEndOfMonth(d, m, y):
    input_dt = datetime(y, m, d)
    # input_dt = datetime(2022, 2, 13)
    # print("The original date is:", input_dt.date())
    # monthrange() to gets the date range
    # year = 2022, month = 9
    res = calendar.monthrange(input_dt.year, input_dt.month)
    lastDay = res[1]
    return lastDay == datetime.today().day

# isEndOfMonth(30, 11, 2023)

def getStrCurrentDate():
    now = datetime.now()
    datestr = f"{now.day}-{now.month}-{now.year}"
    return datestr

def findCurrentDateRowIndex():
    datecolumn_list = currentMonthSheet.getColumn(1)

    datestr = getStrCurrentDate()


    last_found_dateformat_row_index = -1
    # isFoundDate = False
    for j, entrydate in enumerate(datecolumn_list, 1):
        if entrydate.count("-") == 2:
            last_found_dateformat_row_index = j
        # "".count()
        # print(entrydate, "<--------->", datestr)
        if datestr.lower() == entrydate.lower():
            return j, datestr
            # isFoundDate = True
    # return last_found_dateformat_row_index
    now = datetime.now()
    
    last_found_dateformat_row_index += 2
    currentMonthSheet[1, last_found_dateformat_row_index] = datestr
    currentMonthSheet[2, last_found_dateformat_row_index] = 'thb to jyp'
    currentMonthSheet[2, last_found_dateformat_row_index + 1] = 'jyp to thb'
    
    if isEndOfMonth(now.day, now.month, now.year):
        # create new date on new month
        # last_found_dateformat_row_index += 2
        createNewSheetWithSettingFirstDate(
            currentMonthSheet.getRow(1),
              now.strftime("%B"),
            datestr
        )
        # currentMonthSheet[1, last_found_dateformat_row_index] = datestr
        
    return -1, 'error not found today date on datasheet in column A-? => created new date to sheet at row index = ' + str(last_found_dateformat_row_index)
            
# findCurrentDateRowIndex()

def findCurrentColumnIndexHrMnt():
    # rowIndex, daytoday = findCurrentDateRowIndex()
    
    timeHrMnts = currentMonthSheet.getRow(1)

    now = datetime.now()
    hrnow = now.hour
    # print(hrnow)

    columnCurrentHrMnt = -1
    isFoundHrMnt = False
    for j, timeHrMnts in enumerate(timeHrMnts, 1):
        # print(entrydate, "<--------->", datestr)
        entryhr = timeHrMnts.split(":")[0]
        ...
        if entryhr.lower() == str(hrnow).lower():
            return j, "found hr at column " + str(j)
        # if .lower() == entrydate.lower():
        #     isFoundDate = True

# findCurrentColumnIndexHrMnt()

    
# def createNewTimeStampWithCurrencyData():
def createNewSheetWithSettingFirstDate(firstRow, newMonthName, startDateStr):
    global currentMonthSheet
    # currentMonthSheet.refresh()
    print("START NEW MONTH : ", newMonthName)
    currentMonthSheet.spreadsheet.createSheet(title=newMonthName)
    # currentMonthSheet.
    currentMonthSheet = sheet[newMonthName]
    print(firstRow)
    
    currentMonthSheet.updateRow(1, firstRow)
    currentMonthSheet[1, 2] = startDateStr
    currentMonthSheet[2, 2] = 'thb to jyp'
    currentMonthSheet[2, 3] = 'jyp to thb'


def oneShotRun():
    rowIndex, rowdate = findCurrentDateRowIndex()
    colIndex, colHr = findCurrentColumnIndexHrMnt()
    
    if rowIndex == -1:
        print("Error row data not found")
        print(rowdate)
    else: # success found row
        if colIndex == -1:
            print("Erro col data not found")
            print(colHr)
        else: # success both row & col
            print("Writting data to sheet")
            # for thb to jyp
            currentMonthSheet[colIndex, rowIndex] = one_thb_to_jpy
            # for jpy to thb
            currentMonthSheet[colIndex, rowIndex + 1] = one_jpy_to_thb

if __name__ == '__main__':
    if response.status_code == 200:
        api_data = response.json()
        jpy_per_1_usd = int(api_data['rates']['JPY'])
        thb_per_1_usd = int(api_data['rates']['THB'])
    
        one_thb_to_jpy = jpy_per_1_usd / thb_per_1_usd
        one_jpy_to_thb = 1 / one_thb_to_jpy
        print("thb to jpy", one_thb_to_jpy)
        print("jpy to thb", one_jpy_to_thb)
    else:
        print(f"Error: Unable to fetch data from the API. Status code: {response.status_code}")
    
    
    sheet = ezsheets.Spreadsheet('1j9R0dvNIIVQyBBMHjEySVySrEwy7wxsH6LrgDz0Zfe0')
    print("Title of This Sheet is = ", sheet.title)
    current_month = datetime.now().strftime("%B")
    currentMonthSheet = sheet[current_month]

    oneShotRun()

    schedule.every(1).hours.do(oneShotRun)
    while True: 
        schedule.run_pending() 
        time.sleep(1)
# Out:
# Requirement already satisfied: google-api-python-client in /Users/rio/miniconda3/lib/python3.11/site-packages (2.108.0)
# Requirement already satisfied: google-auth-httplib2 in /Users/rio/miniconda3/lib/python3.11/site-packages (0.1.1)
# Requirement already satisfied: google-auth-oauthlib in /Users/rio/miniconda3/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (2.23.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (2.14.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.29.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/rio/miniconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)
# Requirement already satisfied: ezsheets in /Users/rio/miniconda3/lib/python3.11/site-packages (2023.8.11)
# Requirement already satisfied: google-api-python-client in /Users/rio/miniconda3/lib/python3.11/site-packages (from ezsheets) (2.108.0)
# Requirement already satisfied: google-auth-httplib2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from ezsheets) (0.1.1)
# Requirement already satisfied: google-auth-oauthlib in /Users/rio/miniconda3/lib/python3.11/site-packages (from ezsheets) (1.1.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client->ezsheets) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client->ezsheets) (2.23.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client->ezsheets) (2.14.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-python-client->ezsheets) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth-oauthlib->ezsheets) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (4.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (2.29.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->ezsheets) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->ezsheets) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/rio/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->ezsheets) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client->ezsheets) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->ezsheets) (3.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/rio/miniconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->ezsheets) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rio/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ezsheets) (2023.11.17)
# Requirement already satisfied: schedule in /Users/rio/miniconda3/lib/python3.11/site-packages (1.2.1)
# thb to jpy 4.228571428571429
# jpy to thb 0.23648648648648649
# Title of This Sheet is =  ExchangeRateTHBJYP
# Writting data to sheet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 152
#     150 while True:
#     151     schedule.run_pending()
# --> 152     time.sleep(1)
#
# KeyboardInterrupt:

# %%
# createNewSheetWithSettingFirstDate(
#     currentMonthSheet.getRow(1),
#       # datetime.now().strftime("%B"),
#     "TestMonth",
#     "1-12-2023"
# )
# Out:
# START NEW MONTH :  TestMonth
# ['day', '', '0:00', '1:00', '2:00', '3:00', '4:00', '5:00', '6:00', '7:00', '8:00', '9:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00', '', '']

# %%
# call_me=lambda:None
# call_me=lambda:print("sec")
# def call_me():
#     print("cm")
# schedule.every().seconds.do(call_me)
# schedule.every(1).seconds.do(call_me)
# schedule.clear()
# while True: 
#     schedule.run_pending() 
#     time.sleep(1)
